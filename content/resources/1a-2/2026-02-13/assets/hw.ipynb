# %%
# %matplotlib inline

import csv
import matplotlib.pyplot as plt
from collections import defaultdict

data = defaultdict(list)

with open('data.csv', mode ='r') as file:
       reader = csv.DictReader(file, delimiter='\t')
       for row in reader:
           for key, value in row.items():
               data[key].append(float(value))

ecg = data['voltage']
t = data['time']

# %% [markdown]
# ## Nalezněte čas a nejvyšší hodnotu EKG
# EKG je uloženo v seznamu `ecg`, čas v seznamu `t`

# %%
max_time = 0
max_value = 0

# TODO

# %%
plt.plot(t, ecg)
plt.xlabel('Čas [s]')
plt.ylabel('EKG [mV]')

plt.scatter(max_time, max_value, marker='x', color='red')

plt.show()
