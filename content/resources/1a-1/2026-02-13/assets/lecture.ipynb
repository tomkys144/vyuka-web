# %% [markdown]
# # Složené datové typy
# ## Seznam

# %%
znamky = [1, 2, 1, 3, 1, 5, 2, 4, 1]

# %% [markdown]
# ### 1. Vypište seznam známek

# %%
print(znamky)

for znamka in znamky:
    print(znamka)

print("---")

delka = len(znamky)
pozice = 0

while pozice < delka:
    print(pozice, znamky[pozice])
    pozice += 1

print("---")
for poloha in range(delka):
    print(poloha, znamky[poloha])
# Out:
# [1, 2, 1, 3, 1, 5, 2, 4, 1]
# 1
# 2
# 1
# 3
# 1
# 5
# 2
# 4
# 1
# ---
# 0 1
# 1 2
# 2 1
# 3 3
# 4 1
# 5 5
# 6 2
# 7 4
# 8 1
# ---
# 0 1
# 1 2
# 2 1
# 3 3
# 4 1
# 5 5
# 6 2
# 7 4
# 8 1

# %% [markdown]
# ### 2. Vypište první 3 známky

# %%
pos = 0
while pos < 3:
    print(znamky[pos])
    pos += 1

znamky[:3]
# Out:
# 1
# 2
# 1
# [1, 2, 1]

# %% [markdown]
# ### 3. Vypište poslední tři známky

# %%
znamky[-3:]
# Out:
# [2, 4, 1]

# %% [markdown]
# ### 4. Přidejte známku 2 na konec seznamu

# %%
znamky.append(2)
print(znamky)
# Out:
# [1, 2, 1, 3, 1, 5, 2, 4, 1, 2]

# %% [markdown]
# ### 5. Student si test za 5 opravil na 2, proveďte tuto opravu i v seznamu

# %%
znamky[5] = 2
print(znamky)
# Out:
# [1, 2, 1, 3, 1, 2, 2, 4, 1, 2]

# %% [markdown]
# ### 6. Vypočítejte průměr známek

# %%
soucet = 0
for znamka in znamky:
    soucet += znamka

print(soucet)

prumer = soucet / len(znamky)
print(prumer)
# Out:
# 19
# 1.9

# %% [markdown]
# ### 7. (BONUS) Najděte polohu nejhorší známky

# %%
poloha = -1
nejhorsi_znamka = -1

for pos in range(len(znamky)):
    znamka = znamky[pos]
    if znamka > nejhorsi_znamka:
        nejhorsi_znamka = znamka
        poloha = pos

print(poloha, nejhorsi_znamka)
print(znamky)
# Out:
# 7 4
# [1, 2, 1, 3, 1, 2, 2, 4, 1, 2]

# %% [markdown]
# ## Slovník

# %%
car1 = {
    'manufacturer': 'Skoda',
    'model': 'Fabia I',
    'year': 2006,
    'engine': '1.2 HTP',
    'power': 40,
    'price_czk': 45000
}

# %% [markdown]
# ### 1. Vypište rok výroby vozidla

# %%
# TODO

# %% [markdown]
# ### 2. Vypište výkon vozidla

# %%
# TODO

# %% [markdown]
# ### 3. Po měření se zjistilo, že během let ztratila Fabia 5 kW, upravte inforamci ve slovníku

# %%
# TODO

# %% [markdown]
# ### 4. Mnoho zákazníků se ptá, jakou barvu má vůz. Přidejte informaci že je zelený

# %%
# TODO

# %% [markdown]
# ### 5. Vůz bychom rádi prodávali i na slovensku, přidejte parametr `price_eur`. Kurz použijte _1 EUR = 24.5 CZK_

# %%
# TODO

# %% [markdown]
# ### 6. Přijali jsme nové vozidlo. Vytvořte pro něj další kartu obsahující stejné inforamce (parametry jsou na Vás)

# %%
# TODO

# %% [markdown]
# ### 7. Posílat informace o jednotlivých vozech je nepraktické, udělejte seznam všech dostupných vůzů

# %%
# TODO
